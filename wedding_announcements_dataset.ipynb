# %%
import pandas as pd

# %%
#load the data 
df = pd.read_csv("https://github.com/TheUpshot/nyt_weddings/raw/master/nyt_wedding_announcements.csv")

# %%
#sample of 5 lines of the dataframe
df.head()
# Out:
#                                                  url name_status  bride_age  \
# 0  http://www.nytimes.com/1985/12/01/style/myra-c...     keeping        NaN
# 1  http://www.nytimes.com/1985/12/22/style/susan-...      taking        NaN
# 2  http://www.nytimes.com/1985/11/03/style/andrea...      taking        NaN
# 3  http://www.nytimes.com/1985/11/10/style/laetit...     keeping        NaN
# 4  http://www.nytimes.com/1985/10/06/style/leslie...     keeping        NaN
#
#    groom_age
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
#info on the dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7835 entries, 0 to 7834
# Data columns (total 4 columns):
# url            7835 non-null object
# name_status    7835 non-null object
# bride_age      6512 non-null float64
# groom_age      6468 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 306.1+ KB

# %%
#learning more about the dataset
df.describe()
# Out:
#          bride_age    groom_age
# count  6512.000000  6468.000000
# mean     30.457156    32.577767
# std       6.126452     7.517557
# min      20.000000    16.000000
# 25%      27.000000    28.000000
# 50%      29.000000    31.000000
# 75%      32.000000    35.000000
# max      90.000000    92.000000

# %%
#sorting your dataframe by a column 
df.sort(columns='name_status')
# Out:
#                                                     url name_status  \
# 2882  http://www.nytimes.com/1995/06/25/style/weddin...  both names
# 5885  http://www.nytimes.com/2010/10/17/fashion/wedd...  both names
# 1635  http://www.nytimes.com/1990/10/14/style/linda-...  both names
# 4801  http://www.nytimes.com/2000/06/25/style/weddin...  both names
# 2804  http://www.nytimes.com/1995/06/25/style/weddin...  both names
# 1050  http://www.nytimes.com/1990/10/15/style/ann-ki...  both names
# 3317  http://www.nytimes.com/1995/08/27/style/weddin...  both names
# 1052  http://www.nytimes.com/1990/10/15/style/lisa-e...  both names
# 7592  http://www.nytimes.com/2014/11/16/fashion/wedd...  both names
# 1642  http://www.nytimes.com/1990/06/11/style/ivy-s-...  both names
# 2894  http://www.nytimes.com/1995/06/18/style/weddin...  both names
# 1111  http://www.nytimes.com/1990/04/08/style/miss-w...  both names
# 1644  http://www.nytimes.com/1990/05/27/style/miss-b...  both names
# ...
